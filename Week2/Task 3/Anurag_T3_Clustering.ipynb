# %% [markdown]
# <a href="https://colab.research.google.com/github/Anurag-0-1-A/Anurag-0-1-A/blob/main/Week2/Task%203/Anurag_T3_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading the data from the dataset

# %%
data = pd.read_csv("/content/wine-clustering.csv")
print(data)
# Out:
#      Alcohol  Malic_Acid   Ash  ...   Hue  OD280  Proline
# 0      14.23        1.71  2.43  ...  1.04   3.92     1065
# 1      13.20        1.78  2.14  ...  1.05   3.40     1050
# 2      13.16        2.36  2.67  ...  1.03   3.17     1185
# 3      14.37        1.95  2.50  ...  0.86   3.45     1480
# 4      13.24        2.59  2.87  ...  1.04   2.93      735
# ..       ...         ...   ...  ...   ...    ...      ...
# 173    13.71        5.65  2.45  ...  0.64   1.74      740
# 174    13.40        3.91  2.48  ...  0.70   1.56      750
# 175    13.27        4.28  2.26  ...  0.59   1.56      835
# 176    13.17        2.59  2.37  ...  0.60   1.62      840
# 177    14.13        4.10  2.74  ...  0.61   1.60      560
#
# [178 rows x 13 columns]

# %% [markdown]
# ## Dropping the other columns

# %%
data.drop(['Ash','Ash_Alcanity','Magnesium','Total_Phenols','Flavanoids','Nonflavanoid_Phenols','Proanthocyanins','Color_Intensity','Hue','OD280','Proline'], axis=1, inplace=True)
data
# Out:
#      Alcohol  Malic_Acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %% [markdown]
# ## Splitting the data

# %%
X = data.iloc[:,:].values
x1= data.iloc[:,0].values
x2= data.iloc[:,1].values

# %% [markdown]
# ## PLotting the splitted data

# %%
plt.scatter(x1, x2)
plt.plot()
# Out:
# []

# %% [markdown]
# ## Fitting the data into the K-means algorithm and calculating the centroids

# %%
from sklearn.cluster import KMeans
# Number of clusters
kmeans = KMeans(n_clusters=3)
# Getting the cluster labels
labels = kmeans.fit_predict(data)
data["KMeans"]= labels
# Centroid values
centroids = kmeans.cluster_centers_
print("Centroid values")
print(centroids)
# Out:
# Centroid values
# [[12.21349206  1.6531746 ]
#  [13.0632      3.8948    ]
#  [13.71538462  1.79969231]]

# %%
print(data)
# Out:
#      Alcohol  Malic_Acid  KMeans
# 0      14.23        1.71       2
# 1      13.20        1.78       2
# 2      13.16        2.36       2
# 3      14.37        1.95       2
# 4      13.24        2.59       2
# ..       ...         ...     ...
# 173    13.71        5.65       1
# 174    13.40        3.91       1
# 175    13.27        4.28       1
# 176    13.17        2.59       2
# 177    14.13        4.10       1
#
# [178 rows x 3 columns]

# %%
len(X)
# Out:
# 178

# %% [markdown]
# ##Plotting the clusters and centroids

# %%
k=3
colors = ['r', 'g', 'b']
fig, ax = plt.subplots()
for i in range(k):
        points = np.array([X[j] for j in range(len(X)) if labels[j] == i])
        ax.scatter(points[:, 0], points[:, 1], c=colors[i])       
ax.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=500)
